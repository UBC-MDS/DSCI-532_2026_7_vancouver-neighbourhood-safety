# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/raw/crimedata_csv_AllNeighbourhoods_2025.csv')

# %%
df.head()
# Out:
#                          TYPE  YEAR  MONTH  DAY  HOUR  MINUTE  \
# 0  Break and Enter Commercial  2025     11   25     0       0
# 1  Break and Enter Commercial  2025     11   29    18      53
# 2  Break and Enter Commercial  2025      1    2     0       0
# 3  Break and Enter Commercial  2025      6   10    19      27
# 4  Break and Enter Commercial  2025      1   13     3      43
#
#      HUNDRED_BLOCK NEIGHBOURHOOD            X             Y
# 0  10XX PACIFIC ST      West End  490246.7971  5.458367e+06
# 1  10XX PACIFIC ST      West End  490246.7971  5.458367e+06
# 2  10XX PACIFIC ST      West End  490258.8902  5.458368e+06
# 3  10XX PACIFIC ST      West End  490298.1327  5.458317e+06
# 4   10XX ROBSON ST      West End  491036.3006  5.458994e+06

# %%
df.shape
# Out:
# (32411, 10)

# %%
df.columns = df.columns.str.lower()

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 32404 entries, 0 to 32410
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   type           32404 non-null  str
#  1   year           32404 non-null  int64
#  2   month          32404 non-null  int64
#  3   day            32404 non-null  int64
#  4   hour           32404 non-null  int64
#  5   minute         32404 non-null  int64
#  6   hundred_block  32404 non-null  str
#  7   neighbourhood  32404 non-null  str
#  8   x              32404 non-null  float64
#  9   y              32404 non-null  float64
# dtypes: float64(2), int64(5), str(3)
# memory usage: 2.7 MB

# %%
df.isnull().sum()
# Out:
# type             0
# year             0
# month            0
# day              0
# hour             0
# minute           0
# hundred_block    0
# neighbourhood    8
# x                0
# y                0
# dtype: int64

# %%
df['neighbourhood'].isnull().sum()
# Out:
# np.int64(7)

# %%
df[df['neighbourhood'].isna()]
# Out:
#                                                     type  year  month  day  \
# 9805                            Offence Against a Person  2025     10    4
# 9808                            Offence Against a Person  2025      1   19
# 9810                            Offence Against a Person  2025      8    1
# 9811                            Offence Against a Person  2025      3   15
# 10533                           Offence Against a Person  2025      7   19
# 30984  Vehicle Collision or Pedestrian Struck (with I...  2025      1   17
# 31887  Vehicle Collision or Pedestrian Struck (with I...  2025      3   27
# 31888  Vehicle Collision or Pedestrian Struck (with I...  2025      5   14
#
#        hour  minute              hundred_block neighbourhood            x  \
# 9805      0       0  OFFSET TO PROTECT PRIVACY           NaN       0.0000
# 9808      0       0  OFFSET TO PROTECT PRIVACY           NaN       0.0000
# 9810      0       0  OFFSET TO PROTECT PRIVACY           NaN       0.0000
# 9811      0       0  OFFSET TO PROTECT PRIVACY           NaN       0.0000
# 10533     0       0  OFFSET TO PROTECT PRIVACY           NaN       0.0000
# 30984    12      49        15XX GRANVILLE BRDG           NaN  490358.4244
# 31887    15       7             99XXXX UNKNOWN           NaN       0.0000
# 31888    17      13             99XXXX UNKNOWN           NaN       0.0000
#
#                  y
# 9805         0.000
# 9808         0.000
# 9810         0.000
# 9811         0.000
# 10533        0.000
# 30984  5457799.194
# 31887        0.000
# 31888        0.000

# %%
df[df['X'] == 490358.4244]
# Out:
#                                                     TYPE  YEAR  MONTH  DAY  \
# 24826                                 Theft from Vehicle  2025      8   19
# 30065                                   Theft of Bicycle  2025      4   10
# 30984  Vehicle Collision or Pedestrian Struck (with I...  2025      1   17
#
#        HOUR  MINUTE        HUNDRED_BLOCK NEIGHBOURHOOD            X  \
# 24826    17       5  15XX GRANVILLE BRDG      Fairview  490358.4244
# 30065    15       6  15XX GRANVILLE BRDG      Fairview  490358.4244
# 30984    12      49  15XX GRANVILLE BRDG           NaN  490358.4244
#
#                  Y
# 24826  5457799.194
# 30065  5457799.194
# 30984  5457799.194

# %%
# replace missing NaN value with 'Fairview' in the 'neighbourhood'
df.loc[30984, "neighbourhood"] = "Fairview"

# %%
# drop rows with missing values in the 'neighbourhood' column
df.dropna(subset=['neighbourhood'], inplace=True)

# %%
# feature engineer time of day column

def time_of_day(hour):
    if  4 <= hour <= 11:
        return "Morning"
    elif 12 <= hour <= 16:
        return "Afternoon"
    else:
        return "Evening/Night"

# %%
df['time_of_day'] = df['hour'].apply(time_of_day)

# %%
df.head(20)
# Out:
#                           type  year  month  day  hour  minute  \
# 0   Break and Enter Commercial  2025     11   25     0       0
# 1   Break and Enter Commercial  2025     11   29    18      53
# 2   Break and Enter Commercial  2025      1    2     0       0
# 3   Break and Enter Commercial  2025      6   10    19      27
# 4   Break and Enter Commercial  2025      1   13     3      43
# 5   Break and Enter Commercial  2025      3   27    13       0
# 6   Break and Enter Commercial  2025      3   27    14      19
# 7   Break and Enter Commercial  2025     10   16    23      23
# 8   Break and Enter Commercial  2025     11   28     2      55
# 9   Break and Enter Commercial  2025      8   13    18      29
# 10  Break and Enter Commercial  2025      3   16     3       7
# 11  Break and Enter Commercial  2025     11   18     0      37
# 12  Break and Enter Commercial  2025      4   24     2      23
# 13  Break and Enter Commercial  2025      8   20     8       0
# 14  Break and Enter Commercial  2025     10   26    10      56
# 15  Break and Enter Commercial  2025     11   11     6      27
# 16  Break and Enter Commercial  2025      2   10    10      34
# 17  Break and Enter Commercial  2025      9   30     5      48
# 18  Break and Enter Commercial  2025      2   17     6      58
# 19  Break and Enter Commercial  2025      2    7    14      30
#
#           hundred_block              neighbourhood            x             y  \
# 0       10XX PACIFIC ST                   West End  490246.7971  5.458367e+06
# 1       10XX PACIFIC ST                   West End  490246.7971  5.458367e+06
# 2       10XX PACIFIC ST                   West End  490258.8902  5.458368e+06
# 3       10XX PACIFIC ST                   West End  490298.1327  5.458317e+06
# 4        10XX ROBSON ST                   West End  491036.3006  5.458994e+06
# 5     10XX SE MARINE DR                     Sunset  493873.1291  5.450919e+06
# 6     10XX SE MARINE DR                     Sunset  493873.1291  5.450919e+06
# 7     10XX SE MARINE DR                     Sunset  493873.1291  5.450919e+06
# 8     10XX SE MARINE DR                     Sunset  493875.6666  5.450919e+06
# 9       10XX STATION ST                 Strathcona  492788.6724  5.458075e+06
# 10      10XX STATION ST                 Strathcona  492837.9336  5.458068e+06
# 11      10XX STATION ST                 Strathcona  492837.9336  5.458068e+06
# 12    10XX SW MARINE DR                    Marpole  490426.4215  5.450190e+06
# 13    10XX SW MARINE DR                    Marpole  490456.6943  5.450205e+06
# 14      10XX W 42ND AVE                   Oakridge  490639.4061  5.453373e+06
# 15       10XX W 7TH AVE                   Fairview  490670.7998  5.456948e+06
# 16  10XX W BROADWAY AVE                   Fairview  490670.5840  5.456744e+06
# 17  10XX W BROADWAY AVE                   Fairview  490670.5840  5.456744e+06
# 18    10XX W GEORGIA ST  Central Business District  491115.4503  5.459163e+06
# 19    10XX W GEORGIA ST  Central Business District  491115.7520  5.459163e+06
#
#       time_of_day
# 0   Evening/Night
# 1   Evening/Night
# 2   Evening/Night
# 3   Evening/Night
# 4   Evening/Night
# 5       Afternoon
# 6       Afternoon
# 7   Evening/Night
# 8   Evening/Night
# 9   Evening/Night
# 10  Evening/Night
# 11  Evening/Night
# 12  Evening/Night
# 13        Morning
# 14        Morning
# 15        Morning
# 16        Morning
# 17        Morning
# 18        Morning
# 19      Afternoon

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/raw/crimedata_csv_AllNeighbourhoods_2025.csv')

# %%
df.head()
# Out:
#                          TYPE  YEAR  MONTH  DAY  HOUR  MINUTE  \
# 0  Break and Enter Commercial  2025     11   25     0       0
# 1  Break and Enter Commercial  2025     11   29    18      53
# 2  Break and Enter Commercial  2025      1    2     0       0
# 3  Break and Enter Commercial  2025      6   10    19      27
# 4  Break and Enter Commercial  2025      1   13     3      43
#
#      HUNDRED_BLOCK NEIGHBOURHOOD            X             Y
# 0  10XX PACIFIC ST      West End  490246.7971  5.458367e+06
# 1  10XX PACIFIC ST      West End  490246.7971  5.458367e+06
# 2  10XX PACIFIC ST      West End  490258.8902  5.458368e+06
# 3  10XX PACIFIC ST      West End  490298.1327  5.458317e+06
# 4   10XX ROBSON ST      West End  491036.3006  5.458994e+06

# %%
df.shape
# Out:
# (32411, 10)

# %%
df.columns = df.columns.str.lower()

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32411 entries, 0 to 32410
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   type           32411 non-null  str
#  1   year           32411 non-null  int64
#  2   month          32411 non-null  int64
#  3   day            32411 non-null  int64
#  4   hour           32411 non-null  int64
#  5   minute         32411 non-null  int64
#  6   hundred_block  32411 non-null  str
#  7   neighbourhood  32403 non-null  str
#  8   x              32411 non-null  float64
#  9   y              32411 non-null  float64
# dtypes: float64(2), int64(5), str(3)
# memory usage: 2.5 MB

# %%
df.isnull().sum()
# Out:
# type             0
# year             0
# month            0
# day              0
# hour             0
# minute           0
# hundred_block    0
# neighbourhood    8
# x                0
# y                0
# dtype: int64

# %%
df['neighbourhood'].isnull().sum()
# Out:
# np.int64(8)

# %%
df[df['neighbourhood'].isna()]
# Out:
#                                                     type  year  month  day  \
# 9805                            Offence Against a Person  2025     10    4
# 9808                            Offence Against a Person  2025      1   19
# 9810                            Offence Against a Person  2025      8    1
# 9811                            Offence Against a Person  2025      3   15
# 10533                           Offence Against a Person  2025      7   19
# 30984  Vehicle Collision or Pedestrian Struck (with I...  2025      1   17
# 31887  Vehicle Collision or Pedestrian Struck (with I...  2025      3   27
# 31888  Vehicle Collision or Pedestrian Struck (with I...  2025      5   14
#
#        hour  minute              hundred_block neighbourhood            x  \
# 9805      0       0  OFFSET TO PROTECT PRIVACY           NaN       0.0000
# 9808      0       0  OFFSET TO PROTECT PRIVACY           NaN       0.0000
# 9810      0       0  OFFSET TO PROTECT PRIVACY           NaN       0.0000
# 9811      0       0  OFFSET TO PROTECT PRIVACY           NaN       0.0000
# 10533     0       0  OFFSET TO PROTECT PRIVACY           NaN       0.0000
# 30984    12      49        15XX GRANVILLE BRDG           NaN  490358.4244
# 31887    15       7             99XXXX UNKNOWN           NaN       0.0000
# 31888    17      13             99XXXX UNKNOWN           NaN       0.0000
#
#                  y
# 9805         0.000
# 9808         0.000
# 9810         0.000
# 9811         0.000
# 10533        0.000
# 30984  5457799.194
# 31887        0.000
# 31888        0.000

# %%
df[df['x'] == 490358.4244]
# Out:
#                                                     type  year  month  day  \
# 24826                                 Theft from Vehicle  2025      8   19
# 30065                                   Theft of Bicycle  2025      4   10
# 30984  Vehicle Collision or Pedestrian Struck (with I...  2025      1   17
#
#        hour  minute        hundred_block neighbourhood            x  \
# 24826    17       5  15XX GRANVILLE BRDG      Fairview  490358.4244
# 30065    15       6  15XX GRANVILLE BRDG      Fairview  490358.4244
# 30984    12      49  15XX GRANVILLE BRDG           NaN  490358.4244
#
#                  y
# 24826  5457799.194
# 30065  5457799.194
# 30984  5457799.194

# %%
# replace missing NaN value with 'Fairview' in the 'neighbourhood'
df.loc[30984, "neighbourhood"] = "Fairview"

# %%
# drop rows with missing values in the 'neighbourhood' column
df.dropna(subset=['neighbourhood'], inplace=True)

# %%
# feature engineer time of day column

def time_of_day(hour):
    if  4 <= hour <= 11:
        return "Morning"
    elif 12 <= hour <= 17:
        return "Afternoon"
    else:
        return "Evening/Night"

# %%
df['time_of_day'] = df['hour'].apply(time_of_day)

# %%
df.head()
# Out:
#                          type  year  month  day  hour  minute  \
# 0  Break and Enter Commercial  2025     11   25     0       0
# 1  Break and Enter Commercial  2025     11   29    18      53
# 2  Break and Enter Commercial  2025      1    2     0       0
# 3  Break and Enter Commercial  2025      6   10    19      27
# 4  Break and Enter Commercial  2025      1   13     3      43
#
#      hundred_block neighbourhood            x             y    time_of_day
# 0  10XX PACIFIC ST      West End  490246.7971  5.458367e+06  Evening/Night
# 1  10XX PACIFIC ST      West End  490246.7971  5.458367e+06  Evening/Night
# 2  10XX PACIFIC ST      West End  490258.8902  5.458368e+06  Evening/Night
# 3  10XX PACIFIC ST      West End  490298.1327  5.458317e+06  Evening/Night
# 4   10XX ROBSON ST      West End  491036.3006  5.458994e+06  Evening/Night

# %%
df["hundred_block"].unique()
# Out:
# <StringArray>
# [      '10XX PACIFIC ST',        '10XX ROBSON ST',     '10XX SE MARINE DR',
#        '10XX STATION ST',     '10XX SW MARINE DR',       '10XX W 42ND AVE',
#         '10XX W 7TH AVE',   '10XX W BROADWAY AVE',     '10XX W GEORGIA ST',
#     '10XX W HASTINGS ST',
#  ...
#   'X BLOCK N NANAIMO ST',     'X BLOCK SMITHE ST',     'X BLOCK W 8TH AVE',
#   'X BLOCK W CORDOVA ST', 'X BLOCK W HASTINGS ST',   'X BLOCK W PENDER ST',
#     'YEW ST / W 2ND AVE',    'YEW ST / W 4TH AVE', 'YORK AVE / ARBUTUS ST',
#  'YUKON ST / W 12TH AVE']
# Length: 6884, dtype: str

# %%
df.to_csv("../data/processed/vancouver_crime_data_2025.csv", index=False)
